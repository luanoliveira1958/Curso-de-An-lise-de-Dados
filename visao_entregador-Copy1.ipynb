# %%
from haversine import haversine
import plotly.express as px
import plotly.graph_objects as go
import numpy as np
import pandas as pd
import streamlit as st
from streamlit_folium import folium_static
import folium
from PIL import Image
import datetime

import requests


df= pd.read_csv("train.csv")

df1 = df.copy()

linhas_selecionadas=(df1['Delivery_person_Age']!='NaN ')
df1=df1.loc[linhas_selecionadas, :].copy()

linhas_selecionadas=(df1['Road_traffic_density']!='NaN ')
df1=df1.loc[linhas_selecionadas, :].copy()

linhas_selecionadas=(df1['multiple_deliveries']!='NaN ')
df1=df1.loc[linhas_selecionadas, :].copy()

linhas_selecionadas=(df1['Time_taken(min)']!='NaN ')
df1=df1.loc[linhas_selecionadas, :].copy()

#linhas_selecionadas=(df1['Delivery_person_Age']!='NaN ')
#df1=df1.loc[linhas_selecionadas, :].copy()
df1['Delivery_person_Age']=df1['Delivery_person_Age'].astype(int)
df1['Order_Date']=pd.to_datetime(df1['Order_Date'], format='%d-%m-%Y')
df1['Delivery_person_Ratings']=df1['Delivery_person_Ratings'].astype(float)
df1['multiple_deliveries']=df1['multiple_deliveries'].astype(int)
df1['Time_taken(min)']=df1['Time_taken(min)'].astype(str)


#Removendo os espaços dentro de strings/texto/object
df1.loc[:,'ID']=df1.loc[:,'ID'].str.strip()
df1.loc[:,'Road_traffic_density']=df1.loc[:,'Road_traffic_density'].str.strip()
df1.loc[:,'Type_of_order']=df1.loc[:,'Type_of_order'].str.strip()
df1.loc[:,'Type_of_vehicle']=df1.loc[:,'Type_of_vehicle'].str.strip() # Fixed: added parentheses
df1.loc[:,'City']=df1.loc[:,'City'].str.strip()

#Limpando a coluna de Time Taken
# Fixed: removed indentation and corrected DataFrame creation syntax
df1['Time_taken(min)'] = df1['Time_taken(min)'].astype(str)
df1['Time_taken(min)'] = df1['Time_taken(min)'].apply(lambda x: x.split('(min)'))
print(df1['Time_taken(min)'])
#df1['Time_taken(min)']=df1['Time_taken(min)'].apply(lambda x: x.split('(min)')[1])
#df1['Time_taken(min)']=df1['Time_taken(min)'].astype(int)
# Out:
# 0       [,  24]
# 1       [,  33]
# 2       [,  26]
# 3       [,  21]
# 4       [,  30]
#          ...
# 6142    [,  13]
# 6143    [,  21]
# 6144    [,  31]
# 6145    [,  34]
# 6146      [nan]
# Name: Time_taken(min), Length: 5753, dtype: object

# %%
st.header('Marketplace - visão entregador')
image_path = r'C:\Users\Luan\repos\ds_programaçao_python\dataset\dados.jpg'
image = Image.open(image_path)
st.sidebar.image(image, width=120)
st.sidebar.markdown('# Cury Company' )
st.sidebar.markdown('## Fastest Delivery in town' )
st.sidebar.markdown('###___###' )

st.sidebar.markdown('## Selecione uma data limite')

date_slider = st.sidebar.slider(
    'Até qual valor?',
     value=datetime.datetime( 2022, 4, 13),
     min_value=datetime.datetime(2022, 2, 11),
     max_value=datetime.datetime(2022, 4, 6),
     format='DD-MM-YYYY')

st.header(date_slider)  

traffic_options = st.sidebar.multiselect(
    'Quais as condições do trânsito',
    ['Low', 'Medium', 'High', 'Jam'],
    default='Low')
#st.header(df1)

#filtro de data


#filtro de trânsito
linhas_selecionadas = df1['Road_traffic_density'].isin(traffic_options)
df1 = df1.loc[linhas_selecionadas, :]
st.dataframe(df1)
# Out:
# 2025-08-08 13:05:23.208 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 13:05:23.209 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 13:05:23.212 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 13:05:23.218 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 13:05:23.219 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 13:05:23.220 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 13:05:23.220 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 13:05:23.221 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 13:05:23.222 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 13:05:23.223 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 13:05:23.223 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 13:05:23.224 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 13:05:23.225 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 13:05:23.226 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 13:05:23.226 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 13:05:23.227 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 13:05:23.228 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 13:05:23.228 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 13:05:23.229 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 13:05:23.229 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 13:05:23.230 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 13:05:23.231 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 13:05:23.232 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 13:05:23.232 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 13:05:23.232 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 13:05:23.244 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 13:05:23.244 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
#df1.shape

# #Esta função tem a responsabilidade de limpeza do dataframe 
   ### Tipos de Limpeza: 
#   1. Remover os dados NaN
#   2. Mudança do tipo de coluna de dados
#   3. Remover os espaços das variáveis
#   4. Formatação da coluna datas
#   5. Limpeza da coluna tempo
#
def clean_code(df1):
    linhas_selecionadas=(df1['Delivery_person_Age']!='NaN ')
    df1=df1.loc[linhas_selecionadas, :].copy()
    
    linhas_selecionadas=(df1['Road_traffic_density']!='NaN ')
    df1=df1.loc[linhas_selecionadas, :].copy()
    
    linhas_selecionadas=(df1['multiple_deliveries']!='NaN ')
    df1=df1.loc[linhas_selecionadas, :].copy()
    
    linhas_selecionadas=(df1['Time_taken(min)']!='NaN ')
    df1=df1.loc[linhas_selecionadas, :].copy()
    
    #linhas_selecionadas=(df1['Delivery_person_Age']!='NaN ')
    #df1=df1.loc[linhas_selecionadas, :].copy()
    df1['Delivery_person_Age']=df1['Delivery_person_Age'].astype(int)
    df1['Order_Date']=pd.to_datetime(df1['Order_Date'], format='%d-%m-%Y')
    df1['Delivery_person_Ratings']=df1['Delivery_person_Ratings'].astype(float)
    df1['multiple_deliveries']=df1['multiple_deliveries'].astype(int)
    df1['Time_taken(min)']=df1['Time_taken(min)'].astype(str)
    
    
    #Removendo os espaços dentro de strings/texto/object
    df1.loc[:,'ID']=df1.loc[:,'ID'].str.strip()
    df1.loc[:,'Road_traffic_density']=df1.loc[:,'Road_traffic_density'].str.strip()
    df1.loc[:,'Type_of_order']=df1.loc[:,'Type_of_order'].str.strip()
    df1.loc[:,'Type_of_vehicle']=df1.loc[:,'Type_of_vehicle'].str.strip() # Fixed: added parentheses
    df1.loc[:,'City']=df1.loc[:,'City'].str.strip()
    
    #Limpando a coluna de Time Taken
    # Fixed: removed indentation and corrected DataFrame creation syntax
    df1['Time_taken(min)'] = df1['Time_taken(min)'].astype(str)
    df1['Time_taken(min)'] = df1['Time_taken(min)'].apply(lambda x: x.split('(min)'))
    print(df1['Time_taken(min)'])

    return df1
    df = clean_code(df1)

# %%
# Funções
def order_metric(df1):
    cols = ['ID', 'Order_Date']
    df_aux = df1.loc[:, cols].groupby('Order_Date').count().reset_index()
    fig = px.bar(df_aux, x='Order_Date', y='ID')
    return fig  # provavelmente você quer retornar a figura, não o df1

def traffic_order_share(df1):
    df_aux = df1.loc[:,['ID','Road_traffic_density']].groupby('Road_traffic_density').count().reset_index()
    df_aux = df_aux.loc[df_aux['Road_traffic_density']!="NaN ",:]
    df_aux['entregas_perc'] = df_aux['ID'] / df_aux['ID'].sum()
    fig = px.pie(df_aux, values='entregas_perc', names='Road_traffic_density' )
    return fig

def traffic_orde_city(df1):
    df_aux = df1.loc[:,['ID','City','Road_traffic_density']].groupby(['City','Road_traffic_density']).count().reset_index()
    fig = px.scatter(df_aux, x='City', y='Road_traffic_density', size='ID', color='City' )
    return fig



def order_by_week(df1): 
    df1['week_of_year'] = df1['Order_Date'].dt.strftime('%U' )
    df_aux = df1.loc[:, ['ID','week_of_year']].groupby('week_of_year').count().reset_index()
    fig = px.line(df_aux, x='week_of_year', y='ID' )  # Cria o gráfico normalmente
    return fig    


def order_share_by_week(df1):
    df_aux1 = df1.loc[:, ['ID','week_of_year']].groupby('week_of_year' ).count().reset_index()
    df_aux2 = df1.loc[:, ['Delivery_person_ID','week_of_year']].groupby('week_of_year').nunique().reset_index()
    df_aux = pd.merge(df_aux1, df_aux2, how='inner', on='week_of_year')
    df_aux['order_by_delivery'] = df_aux['ID'] / df_aux['Delivery_person_ID']
    fig = px.line(df_aux, x='week_of_year', y='order_by_delivery')
    return fig


def country_maps(df1):
    df_aux = df1.loc[:,['City','Road_traffic_density','Delivery_location_latitude','Delivery_location_longitude']].groupby(['City','Road_traffic_density']).median().reset_index()
        
    map = folium.Map()
    for index, location_info in df_aux.iterrows():
        folium.Marker([location_info['Delivery_location_latitude'],
                       location_info['Delivery_location_longitude']],
                      popup = location_info[['City','Road_traffic_density']]).add_to(map)
        folium_static(map, width=1024, height=600)
    return None

# %%
fig = order_metric(df1)
st.markdown('#Orders by Day')
st.plotly_chart(fig, use_container_width = True)
# Out:
# 2025-08-08 16:29:52.718 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 16:29:52.718 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 16:29:52.720 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 16:29:52.721 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 16:29:52.721 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 16:29:52.722 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
tab1, tab2, tab3 = st.tabs(['Visão Gerencial', 'Visão Tática', 'Visão Geográfica'])

# TAB 1 - Visão Gerencial
with tab1:
    with st.container():
        fig = order_metric(df1)
        st.markdown('# Orders by Day')
        st.plotly_chart(fig, use_container_width=True)

    with st.container():
        col1, col2 = st.columns(2)

        with col1:
            st.header("Traffic Order Share")
            st.plotly_chart(fig, use_container_width=True)
            fig = traffic_order_share(df1)

        with col2:
            st.header("Traffic Order City")
            st.plotly_chart(fig, use_container_width=True)
            fig = traffic_order_city(df1)

# TAB 2 - Visão Tática
with tab2:
    with st.container():
        fig = order_by_week(df1)
        st.markdown("Order by Week")
        st.plotly_chart(fig, use_container_width=True)

    with st.container():
        fig = order_share_by_week(df1)
        st.markdown("# Order Share by Week")
        st.plotly_chart(fig, use_container_width=True)

# TAB 3 - Visão Geográfica
with tab3:
    st.markdown("# Country Maps")
    country_maps(df1)
# Out:
# 2025-08-08 17:43:40.835 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 17:43:40.838 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 17:43:40.839 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 17:43:40.841 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 17:43:40.843 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 17:43:40.881 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 17:43:40.882 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 17:43:40.884 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 17:43:40.885 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 17:43:40.886 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 17:43:40.887 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 17:43:40.888 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 17:43:40.889 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 17:43:40.889 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 17:43:40.890 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 17:43:40.893 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 17:43:40.894 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 17:43:40.897 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 17:43:40.898 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 17:43:40.899 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 17:43:40.899 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 16
#      14     st.header("Traffic Order Share")
#      15     st.plotly_chart(fig, use_container_width=True)
# ---> 16     fig = traffic_order_share(df1)
#      18 with col2:
#      19     st.header("Traffic Order City")
#
# NameError: name 'traffic_order_share' is not defined

# %%
tab1, tab2, tab3 = st.tabs(['Visão Gerencial','Visão Tática','Visão Geográfica'])

def order_metric(df1):
    cols = ['ID', 'Order_Date']
    df_aux = df1.loc[:, cols].groupby('Order_Date').count().reset_index()
    fig = px.bar(df_aux, x='Order_Date', y='ID')
    return fig  # provavelmente você quer retornar a figura, não o df1

with tab1:
    with st.container():
        st.markdown('# Orders by Day')
        fig = order_metric(df1)  # chama a função para criar o gráfico
        st.plotly_chart(fig, use_container_width=True)
# Out:
# 2025-08-08 13:29:34.579 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 13:29:34.580 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 13:29:34.581 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 13:29:34.581 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 13:29:34.582 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 13:29:34.582 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 13:29:34.583 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 13:29:34.874 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 13:29:34.875 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 13:29:34.876 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 13:29:34.876 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
###############################################################
#Layout no Streamlit
###############################################################

tab1, tab2, tab3 = st.tabs(['Visão Gerencial','Visão Tática','Visão Geográfica'])
with tab1:
    with st.container():
        #Order Metric
        #Visão - Entregador
        #coluna
        st.markdown('# Orders by Day')
        cols = ['ID','Order_Date']
        #Seleção de linhas
        df_aux = df1.loc[:, cols].groupby('Order_Date').count().reset_index()
        #Desenhar o gráfico de linhas
        #plotly
        
        fig = px.bar(df_aux, x='Order_Date', y='ID' )
        st.plotly_chart( fig, use_container_width= True  )

    with st.container():
         col1, col2 = st.columns(2)
        
         with col1:
           # st.markdown('#coluna 1')
             fig = traffic_order_share(df1)
             st.header("Traffic Order Share")
             st.plotly_chart(fig, use_container_with=True)
             
            
         with col2:
             fig = traffic_order_city(df1)
             st.header("Traffic Order City")
             st.plotly_chart(fig, use_container_with=True)

                         
         #  st.markdown('#coluna 2')
        #st.markdown("#teste01")
       # st.markdown("#teste0r")
    
with tab2:
     with st.container():
         st.markdown("Order by Week")
         st.plotly_chart(fig, use_container_width=True)  # Exibe o gráfico com ajuste ao container
         fig = order_by_week(df1)
         
                 
     with st.container():
        st.markdown("#Order Share by Week")
        st.plotly_chart(fig, use_container_width= True)
        fig = order_share_by_week(df1)
    
with tab3:
    st.markdown("# Country Maps")
    country_maps(df1)
